# %% [markdown]
# <a href="https://colab.research.google.com/github/tasnim-shamsuddin/Bank-Customer-Churn-Prediction-/blob/main/experiments_NN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/tasnim-shamsuddin/Bank-Customer-Churn-Prediction-
# Out:
# Cloning into 'Bank-Customer-Churn-Prediction-'...
# remote: Enumerating objects: 7001, done.
# remote: Counting objects: 100% (787/787), done.
# remote: Compressing objects: 100% (774/774), done.
# remote: Total 7001 (delta 47), reused 148 (delta 11), pack-reused 6214 (from 3)
# Receiving objects: 100% (7001/7001), 48.81 MiB | 14.59 MiB/s, done.
# Resolving deltas: 100% (813/813), done.

# %% [markdown]
# ANN IMPLEMENTATION

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
! git clone https://github.com/tasnim-shamsuddin/Bank-Customer-Churn-Prediction-
# Out:
# fatal: destination path 'Bank-Customer-Churn-Prediction-' already exists and is not an empty directory.

# %%
# !pwd
# Out:
# /content/Bank-Customer-Churn-Prediction-/Bank-Customer-Churn-Prediction-/Bank-Customer-Churn-Prediction-/Bank-Customer-Churn-Prediction-

# %%
# %cd Bank-Customer-Churn-Prediction-
# Out:
# /content/Bank-Customer-Churn-Prediction-/Bank-Customer-Churn-Prediction-/Bank-Customer-Churn-Prediction-/Bank-Customer-Churn-Prediction-/Bank-Customer-Churn-Prediction-

# %%
# !ls
# Out:
# Churn_Modelling.csv  onehot_encoder.pkl  scaler.pkl  X_train.pkl
# experiments.ipynb    README.md		 venv	     y_test.pkl
# label_encoder.pkl    requirements.txt	 X_test.pkl  y_train.pkl

# %%
import pickle

with open("X_train.pkl", "rb") as f:
    X_train = pickle.load(f)

with open("X_test.pkl", "rb") as f:
    X_test = pickle.load(f)

with open("y_train.pkl", "rb") as f:
    y_train = pickle.load(f)

with open("y_test.pkl", "rb") as f:
    y_test = pickle.load(f)

print(X_train.shape, X_test.shape)
# Out:
# (8000, 12) (2000, 12)

# %%
model=Sequential(
    [
        Dense(64,activation='relu',input_shape=(X_train.shape[1],)),
        Dense(32,activation='relu'),
        Dense(1,activation='sigmoid')
    ]
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
import tensorflow as tf
opt=tf.keras.optimizers.Adam(learning_rate=0.001)

# %%
#compiling the model
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
##set up the tensor board
import datetime
from tensorflow.keras.callbacks import EarlyStopping,TensorBoard
log_dir="logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorflow_callback=TensorBoard(log_dir=log_dir,histogram_freq=1)

# %%
##set up early stopping
early_stop=EarlyStopping(monitor='val_loss',mode='min',verbose=1,patience=5,restore_best_weights=True)

# %%
##Train the model
histroty=model.fit(
    X_train,
    y_train,
    epochs=100,
    validation_data=(X_test,y_test),
    callbacks=[tensorflow_callback,early_stop]
)
# Out:
# Epoch 1/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.7363 - loss: 0.5262 - val_accuracy: 0.8315 - val_loss: 0.3978
# Epoch 2/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8291 - loss: 0.4036 - val_accuracy: 0.8500 - val_loss: 0.3585
# Epoch 3/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8556 - loss: 0.3595 - val_accuracy: 0.8570 - val_loss: 0.3530
# Epoch 4/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8533 - loss: 0.3525 - val_accuracy: 0.8580 - val_loss: 0.3452
# Epoch 5/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8708 - loss: 0.3288 - val_accuracy: 0.8575 - val_loss: 0.3451
# Epoch 6/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8585 - loss: 0.3428 - val_accuracy: 0.8545 - val_loss: 0.3484
# Epoch 7/100
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8621 - loss: 0.3303 - val_accuracy: 0.8560 - val_loss: 0.3445
# Epoch 8/100
# ...
